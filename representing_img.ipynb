# %%
import numpy as np
from matplotlib import pyplot as plt

a = np.zeros((9,9,3), dtype="uint8")

# %%
plt.imshow(a)

# %%
a[2,2,:]
#The three values represents the amount of red, green and blue 
#It goes from 0 to 1(100%)
# Out:
# array([0, 0, 0], dtype=uint8)

# %%
a[2,2,:] = np.array([255,0,0])
# setting a red pixel at this position

# %%
a[2,2,:]
# Out:
# array([1., 0., 0.])

# %%
plt.imshow(a)

# %%
#now we gonna set blue and green pixels
a[2,3,:] = np.array([0,0,255])#blue
a[5,3,:] = np.array([0,0,255])#blue
a[3,3,:] = np.array([0,255,0])#green
a[6,3,:] = np.array([0,255,0])#green
a[6,2,:] = np.array([255,0,0])#red
a[6,6,:] = np.array([0,0,255])#blue
a[2,6,:] = np.array([0,0,255])#blue
a[3,7,:] = np.array([0,0,255])#blue
a[4,7,:] = np.array([0,0,255])#blue
a[5,7,:] = np.array([0,0,255])#blue
a[3,2,:] = np.array([255,0,255])#violet
a[5,2,:] = np.array([255,0,255])#violet

# %%
# reading the image with pyplot from matplotlib
img = plt.imread("img.jpg")

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
img.shape
# Out:
# (1080, 1080, 3)

# %%
plt.imshow(img)

# %%
new_img = np.zeros(img.shape, dtype=img.dtype)

# %%
new_img.shape
# Out:
# (1080, 1080, 3)

# %%
new_img[:,:,2] = img[:,:,2]

# %%
plt.imshow(new_img)
